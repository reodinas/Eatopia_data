# %%
# 전처리한 데이터프레임을 mysql에 저장

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
# 식당데이터

# %%
RESTAURANT = pd.read_csv('RESTAURANT_FINAL.csv', index_col=0)

# %%
RESTAURANT = RESTAURANT.iloc[:,2:-1]

# %%
RESTAURANT
# Out:
#               name  category locCity locDistrict         locDetail  \
# 0              보광호       생선회   인천광역시         강화군  길상면 해안남로619번길 21
# 1             장어마을  장어,먹장어요리   인천광역시         강화군      길상면 해안남로 298
# 2            충남서산집       게요리   인천광역시         강화군      내가면 중앙로 1200
# 3           한옥카페 궁    카페,디저트   인천광역시         강화군  내가면 중앙로1128번길 21
# 4          1박2일 족발     족발,보쌈   인천광역시         강화군        강화읍 북문길 12
# ...            ...       ...     ...         ...               ...
# 18981          힘내소   육류,고기요리   인천광역시          서구           새오개로 37
# 18982         힘센장어  장어,먹장어요리   인천광역시          서구     승학로236번길 20-1
# 18983     힘찬장어 청라점  장어,먹장어요리   인천광역시          서구          중봉대로 800
# 18984         힛트꼬치   일식튀김,꼬치   인천광역시          서구        원창로240번길 3
# 18985  쑝쑝돈까스 인천가좌점       돈가스   인천광역시          서구        장고개로 277-1
#
#                 tel   longitude   latitude  \
# 0      032-937-7111  126.496185  37.598379
# 1      032-937-0592  126.520175  37.610090
# ...

# %%
# db 연결

# %%
host = 'yh-db.cdtkthbhsama.ap-northeast-2.rds.amazonaws.com'
user = 'Eatopia_DB_user'
password = 'dltxhvldk1234db'  # db 비밀번호
db_name = 'Eatopia_DB'

# %%
db_connection_str = f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %%
connection = create_engine(db_connection_str)

# %%
connection
# Out:
# Engine(mysql+pymysql://Eatopia_DB_user:***@yh-db.cdtkthbhsama.ap-northeast-2.rds.amazonaws.com/Eatopia_DB)

# %%
# db의 restaurant 테이블에 저장

# %%
RESTAURANT.to_sql(name='restaurant', con=connection, if_exists='append',index=False)
# Out:
# 18986

# %%
# 메뉴데이터

# %%
MENU = pd.read_csv('MENU_FINAL2.csv', index_col=0)

# %%
MENU
# Out:
#             id  old_restaurantId  restaurantId       menuName  price  \
# 0            1                 2             1        A세트인기대표  59000
# 1            2                 2             1             숭어  25000
# 2            3                 2             1             광어  40000
# 3            4                 2             1             우럭  40000
# 4            5                 2             1             도미  50000
# ...        ...               ...           ...            ...    ...
# 162204  162205             31201         18984  국수(잔치/열무/물냉면)   4000
# 162205  162206             31206         18986         프리미엄카츠   7500
# 162206  162207             31206         18986        큐브치즈카츠1   8500
# 162207  162208             31206         18986        큐브치즈카츠2   9500
# 162208  162209             31206         18986           모둠카츠   9500
#
#                                               description  \
# 0                                    해산물모듬+제철모듬회+매운탕(지리탕)
# ...

# %%
MENU = MENU.iloc[:, 2:]

# %%
MENU
# Out:
#         restaurantId       menuName  price  \
# 0                  1        A세트인기대표  59000
# 1                  1             숭어  25000
# 2                  1             광어  40000
# 3                  1             우럭  40000
# 4                  1             도미  50000
# ...              ...            ...    ...
# 162204         18984  국수(잔치/열무/물냉면)   4000
# 162205         18986         프리미엄카츠   7500
# 162206         18986        큐브치즈카츠1   8500
# 162207         18986        큐브치즈카츠2   9500
# 162208         18986           모둠카츠   9500
#
#                                               description  \
# 0                                    해산물모듬+제철모듬회+매운탕(지리탕)
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# ...

# %%
MENU.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162209 entries, 0 to 162208
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   restaurantId  162209 non-null  int64
#  1   menuName      162209 non-null  object
#  2   price         162209 non-null  int64
#  3   description   64255 non-null   object
#  4   imgUrl        89067 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 7.4+ MB

# %%
MENU['price'].value_counts()
# Out:
# -1         7186
#  8000      6153
#  10000     5714
#  7000      5597
#  6000      5480
#            ...
#  45800        1
#  61800        1
#  56800        1
#  149900       1
#  349000       1
# Name: price, Length: 615, dtype: int64

# %%
# db의 menu 테이블에 저장

# %%
MENU.to_sql(name='menu', con=connection, if_exists='append', index=False)
# Out:
# 162209

# %%
# db 연결 해제

# %%
connection.dispose()
