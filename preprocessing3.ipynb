# %%
# 프로젝트 진행 중 메뉴 가격이 이상하게 들어간 데이터들이 있어서 다시 전처리

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('MENU_FINAL.csv', index_col=0)

# %%
df
# Out:
#             id  old_restaurantId  restaurantId       menuName  price  \
# 0            1                 2             1        A세트인기대표  59000
# 1            2                 2             1             숭어  25000
# 2            3                 2             1             광어  40000
# 3            4                 2             1             우럭  40000
# 4            5                 2             1             도미  50000
# ...        ...               ...           ...            ...    ...
# 162204  162205             31201         18984  국수(잔치/열무/물냉면)   4000
# 162205  162206             31206         18986         프리미엄카츠   7500
# 162206  162207             31206         18986        큐브치즈카츠1   8500
# 162207  162208             31206         18986        큐브치즈카츠2   9500
# 162208  162209             31206         18986           모둠카츠   9500
#
#                                               description  \
# 0                                    해산물모듬+제철모듬회+매운탕(지리탕)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162209 entries, 0 to 162208
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                162209 non-null  int64
#  1   old_restaurantId  162209 non-null  int64
#  2   restaurantId      162209 non-null  int64
#  3   menuName          162209 non-null  object
#  4   price             155990 non-null  object
#  5   description       64255 non-null   object
#  6   imgUrl            89067 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 9.9+ MB

# %%
df['price'].unique()
# Out:
# array(['59000', '25000', '40000', '50000', '30000', '15000', '20000',
#        '60000', '2000', '3000', '8000', '10000', '55000', '120000',
#        '100000', '80000', '70000', '35000', '17000', '7000', '5500',
#        '7500', '6000', '18000', '12000', '5000', '6500', '11000', '9000',
#        '29000', '14000', '13000', '16000', '12900', '27000', '20900',
#        '17900', nan, '15900', '25900', '26900', '45000', '6900', '5900',
#        '6800', '4400', '4500', '3500', '4000', '4800', '13500', '23000',
#        '24000', '19000', '43000', '14900', '11900', '16900', '22900',
#        '8500', '19900', '13900', '1500', '2500', '28000', '20500',
#        '22000', '38000', '34000', '52000', '39000', '48000', '33000',
#        '54000', '49000', '108000', '162000', '216000', '98000', '147000',
#        '196000', '32000', '37000', '9900', '49900', '99900', '27800',
#        '23800', '68000', '42000', '1000', '78000', '130000', '110000',
# ...

# %%
df['price'].nunique()
# Out:
# 821

# %%
# 이상값을 0으로 변경

# %%
df.loc[df['price']=='무료', 'price'] = 0

# %%
df['price'].unique()
# Out:
# array(['59000', '25000', '40000', '50000', '30000', '15000', '20000',
#        '60000', '2000', '3000', '8000', '10000', '55000', '120000',
#        '100000', '80000', '70000', '35000', '17000', '7000', '5500',
#        '7500', '6000', '18000', '12000', '5000', '6500', '11000', '9000',
#        '29000', '14000', '13000', '16000', '12900', '27000', '20900',
#        '17900', nan, '15900', '25900', '26900', '45000', '6900', '5900',
#        '6800', '4400', '4500', '3500', '4000', '4800', '13500', '23000',
#        '24000', '19000', '43000', '14900', '11900', '16900', '22900',
#        '8500', '19900', '13900', '1500', '2500', '28000', '20500',
#        '22000', '38000', '34000', '52000', '39000', '48000', '33000',
#        '54000', '49000', '108000', '162000', '216000', '98000', '147000',
#        '196000', '32000', '37000', '9900', '49900', '99900', '27800',
#        '23800', '68000', '42000', '1000', '78000', '130000', '110000',
# ...

# %%
df.loc[df['price'].isna(), 'price'] = 0

# %%
df['price'].unique()
# Out:
# array(['59000', '25000', '40000', '50000', '30000', '15000', '20000',
#        '60000', '2000', '3000', '8000', '10000', '55000', '120000',
#        '100000', '80000', '70000', '35000', '17000', '7000', '5500',
#        '7500', '6000', '18000', '12000', '5000', '6500', '11000', '9000',
#        '29000', '14000', '13000', '16000', '12900', '27000', '20900',
#        '17900', 0, '15900', '25900', '26900', '45000', '6900', '5900',
#        '6800', '4400', '4500', '3500', '4000', '4800', '13500', '23000',
#        '24000', '19000', '43000', '14900', '11900', '16900', '22900',
#        '8500', '19900', '13900', '1500', '2500', '28000', '20500',
#        '22000', '38000', '34000', '52000', '39000', '48000', '33000',
#        '54000', '49000', '108000', '162000', '216000', '98000', '147000',
#        '196000', '32000', '37000', '9900', '49900', '99900', '27800',
#        '23800', '68000', '42000', '1000', '78000', '130000', '110000',
# ...

# %%
df['price'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df['price'].astype('int')
#
# File ~\anaconda3\envs\lambda39\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\envs\lambda39\lib\site-packages\pandas\core\internals\managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
import sys

# %%
sys.maxsize
# Out:
# 9223372036854775807

# %%
df['price'] = pd.to_numeric(df['price'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162209 entries, 0 to 162208
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                162209 non-null  int64
#  1   old_restaurantId  162209 non-null  int64
#  2   restaurantId      162209 non-null  int64
#  3   menuName          162209 non-null  object
#  4   price             162209 non-null  int64
#  5   description       64255 non-null   object
#  6   imgUrl            89067 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 9.9+ MB

# %%
df['price'].unique()
# Out:
# array([     59000,      25000,      40000,      50000,      30000,
#             15000,      20000,      60000,       2000,       3000,
#              8000,      10000,      55000,     120000,     100000,
#             80000,      70000,      35000,      17000,       7000,
#              5500,       7500,       6000,      18000,      12000,
#              5000,       6500,      11000,       9000,      29000,
#             14000,      13000,      16000,      12900,      27000,
#             20900,      17900,          0,      15900,      25900,
#             26900,      45000,       6900,       5900,       6800,
#              4400,       4500,       3500,       4000,       4800,
#             13500,      23000,      24000,      19000,      43000,
#             14900,      11900,      16900,      22900,       8500,
#             19900,      13900,       1500,       2500,      28000,
#             20500,      22000,      38000,      34000,      52000,
# ...

# %%
df.loc[(df['price'] % 100 != 0), 'price'] = 0

# %%
df.loc[(df['price'] > 500000), 'price'] = 0

# %%
df['price'].unique()
# Out:
# array([ 59000,  25000,  40000,  50000,  30000,  15000,  20000,  60000,
#          2000,   3000,   8000,  10000,  55000, 120000, 100000,  80000,
#         70000,  35000,  17000,   7000,   5500,   7500,   6000,  18000,
#         12000,   5000,   6500,  11000,   9000,  29000,  14000,  13000,
#         16000,  12900,  27000,  20900,  17900,      0,  15900,  25900,
#         26900,  45000,   6900,   5900,   6800,   4400,   4500,   3500,
#          4000,   4800,  13500,  23000,  24000,  19000,  43000,  14900,
#         11900,  16900,  22900,   8500,  19900,  13900,   1500,   2500,
#         28000,  20500,  22000,  38000,  34000,  52000,  39000,  48000,
#         33000,  54000,  49000, 108000, 162000, 216000,  98000, 147000,
#        196000,  32000,  37000,   9900,  49900,  99900,  27800,  23800,
#         68000,  42000,   1000,  78000, 130000, 110000,  18900,  36000,
#         40500,  43500, 140000,  85000, 135000, 115000,  79000,  90000,
# ...

# %%
df.loc[(df['price'] == 0), :]
# Out:
#             id  old_restaurantId  restaurantId  menuName  price  \
# 66          67                13             9      반반피자      0
# 643        644               128            85      갈치조림      0
# 644        645               128            85      젓국갈비      0
# 648        649               128            85  묵은지고등어조림      0
# 655        656               130            87        장어      0
# ...        ...               ...           ...       ...    ...
# 161550  161551             31069         18903    한돈 갈비찜      0
# 161779  161780             31094         18924      삼치구이      0
# 161784  161785             31094         18924      닭도리탕      0
# 161905  161906             31126         18942      가리비찜      0
# 162014  162015             31150         18955      명태조림      0
#
#                               description  \
# 66           입맛에 맞게끔 내 맘대로 반반 선택할 수 있는 피자
# 643                                   NaN
# 644                                   NaN
# ...

# %%
# 이상값을 -1로 변경
# -1일 경우 가격정보없음으로 처리하도록 프로젝트 설계

# %%
df.loc[(df['price'] == 0), 'price'] = -1

# %%
df[df['price'] == -1]
# Out:
#             id  old_restaurantId  restaurantId  menuName  price  \
# 66          67                13             9      반반피자     -1
# 643        644               128            85      갈치조림     -1
# 644        645               128            85      젓국갈비     -1
# 648        649               128            85  묵은지고등어조림     -1
# 655        656               130            87        장어     -1
# ...        ...               ...           ...       ...    ...
# 161550  161551             31069         18903    한돈 갈비찜     -1
# 161779  161780             31094         18924      삼치구이     -1
# 161784  161785             31094         18924      닭도리탕     -1
# 161905  161906             31126         18942      가리비찜     -1
# 162014  162015             31150         18955      명태조림     -1
#
#                               description  \
# 66           입맛에 맞게끔 내 맘대로 반반 선택할 수 있는 피자
# 643                                   NaN
# 644                                   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162209 entries, 0 to 162208
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                162209 non-null  int64
#  1   old_restaurantId  162209 non-null  int64
#  2   restaurantId      162209 non-null  int64
#  3   menuName          162209 non-null  object
#  4   price             162209 non-null  int64
#  5   description       64255 non-null   object
#  6   imgUrl            89067 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 9.9+ MB

# %%
df['price'].unique()
# Out:
# array([ 59000,  25000,  40000,  50000,  30000,  15000,  20000,  60000,
#          2000,   3000,   8000,  10000,  55000, 120000, 100000,  80000,
#         70000,  35000,  17000,   7000,   5500,   7500,   6000,  18000,
#         12000,   5000,   6500,  11000,   9000,  29000,  14000,  13000,
#         16000,  12900,  27000,  20900,  17900,     -1,  15900,  25900,
#         26900,  45000,   6900,   5900,   6800,   4400,   4500,   3500,
#          4000,   4800,  13500,  23000,  24000,  19000,  43000,  14900,
#         11900,  16900,  22900,   8500,  19900,  13900,   1500,   2500,
#         28000,  20500,  22000,  38000,  34000,  52000,  39000,  48000,
#         33000,  54000,  49000, 108000, 162000, 216000,  98000, 147000,
#        196000,  32000,  37000,   9900,  49900,  99900,  27800,  23800,
#         68000,  42000,   1000,  78000, 130000, 110000,  18900,  36000,
#         40500,  43500, 140000,  85000, 135000, 115000,  79000,  90000,
# ...

# %%
# 파일로 저장

# %%
df.to_csv('MENU_FINAL2.csv')

# %%
pd.read_csv('MENU_FINAL2.csv',index_col=0)
# Out:
#             id  old_restaurantId  restaurantId       menuName  price  \
# 0            1                 2             1        A세트인기대표  59000
# 1            2                 2             1             숭어  25000
# 2            3                 2             1             광어  40000
# 3            4                 2             1             우럭  40000
# 4            5                 2             1             도미  50000
# ...        ...               ...           ...            ...    ...
# 162204  162205             31201         18984  국수(잔치/열무/물냉면)   4000
# 162205  162206             31206         18986         프리미엄카츠   7500
# 162206  162207             31206         18986        큐브치즈카츠1   8500
# 162207  162208             31206         18986        큐브치즈카츠2   9500
# 162208  162209             31206         18986           모둠카츠   9500
#
#                                               description  \
# 0                                    해산물모듬+제철모듬회+매운탕(지리탕)
# ...
