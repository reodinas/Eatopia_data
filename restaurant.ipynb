# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("인천광역시_일반음식점 현황_20221230.csv", encoding='cp949')

# %%
df
# Out:
#           연번    인허가관할기관             업소명     업종        업태  \
# 0          1  인천광역시 강화군  (유한)애플이엔씨 인천강화  일반음식점        한식
# 1          2  인천광역시 강화군          (주)보광호  일반음식점        회집
# 2          3  인천광역시 강화군          (주)섬고기  일반음식점       경양식
# 3          4  인천광역시 강화군         (주)장어마을  일반음식점        한식
# 4          5  인천광역시 강화군        (주)충남서산집  일반음식점        한식
# ...      ...        ...             ...    ...       ...
# 32659  32660   인천광역시 서구            힛트꼬치  일반음식점     호프/통닭
# 32660  32661   인천광역시 서구             NaN  일반음식점  식육(숯불구이)
# 32661  32662   인천광역시 서구             힌무발  일반음식점     호프/통닭
# 32662  32663   인천광역시 서구         돈까스 청라점  일반음식점        일식
# 32663  32664   인천광역시 서구          돈까스가좌점  일반음식점        일식
#
#                                                  업소주소 영업상태
# 0                          인천광역시 강화군 선원면 창리 418 외 1필지   정상
# 1                   인천광역시 강화군 길상면 해안남로619번길 21(1동 1층)   정상
# 2                            인천광역시 강화군 길상면 삼랑성길 4(1층)   정상
# 3                              인천광역시 강화군 길상면 해안남로 298   정상
# 4                          인천광역시 강화군 내가면 중앙로 1198(1층)   정상
# ...                                               ...  ...
# 32659                        인천광역시 서구 원창로240번길 3(가정동)   정상
# 32660                  인천광역시 서구 승학로382번길 1(검암동, 104호)   정상
# 32661                     인천광역시 서구 석남로 106(1층 일부 석남동)   정상
# 32662  인천광역시 서구 중봉대로612번길 10-12(109,110호 연희동, 청라프라자2)   정상
# 32663             인천광역시 서구 장고개로 277-1(청운프라자 101호 가좌동)   정상
#
# [32664 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32664 entries, 0 to 32663
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   연번       32664 non-null  int64
#  1   인허가관할기관  32664 non-null  object
#  2   업소명      32663 non-null  object
#  3   업종       32664 non-null  object
#  4   업태       32313 non-null  object
#  5   업소주소     32663 non-null  object
#  6   영업상태     32664 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.7+ MB

# %%
df = df.dropna(axis=0, subset=['업소명', '업소주소'])

# %%
df
# Out:
#           연번    인허가관할기관             업소명     업종     업태  \
# 0          1  인천광역시 강화군  (유한)애플이엔씨 인천강화  일반음식점     한식
# 1          2  인천광역시 강화군          (주)보광호  일반음식점     회집
# 2          3  인천광역시 강화군          (주)섬고기  일반음식점    경양식
# 3          4  인천광역시 강화군         (주)장어마을  일반음식점     한식
# 4          5  인천광역시 강화군        (주)충남서산집  일반음식점     한식
# ...      ...        ...             ...    ...    ...
# 32658  32659   인천광역시 서구            힘찬장어  일반음식점     한식
# 32659  32660   인천광역시 서구            힛트꼬치  일반음식점  호프/통닭
# 32661  32662   인천광역시 서구             힌무발  일반음식점  호프/통닭
# 32662  32663   인천광역시 서구         돈까스 청라점  일반음식점     일식
# 32663  32664   인천광역시 서구          돈까스가좌점  일반음식점     일식
#
#                                                  업소주소 영업상태
# 0                          인천광역시 강화군 선원면 창리 418 외 1필지   정상
# 1                   인천광역시 강화군 길상면 해안남로619번길 21(1동 1층)   정상
# 2                            인천광역시 강화군 길상면 삼랑성길 4(1층)   정상
# 3                              인천광역시 강화군 길상면 해안남로 298   정상
# 4                          인천광역시 강화군 내가면 중앙로 1198(1층)   정상
# ...                                               ...  ...
# 32658                       인천광역시 서구 중봉대로 800(1층 경서동)   정상
# 32659                        인천광역시 서구 원창로240번길 3(가정동)   정상
# 32661                     인천광역시 서구 석남로 106(1층 일부 석남동)   정상
# 32662  인천광역시 서구 중봉대로612번길 10-12(109,110호 연희동, 청라프라자2)   정상
# 32663             인천광역시 서구 장고개로 277-1(청운프라자 101호 가좌동)   정상
#
# [32662 rows x 7 columns]

# %%
df.to_csv('incheon.csv')

# %%
df = pd.read_csv("incheon.csv", index_col=0)

# %%
df
# Out:
#          인허가관할기관             업소명     업종     업태  \
# 0      인천광역시 강화군  (유한)애플이엔씨 인천강화  일반음식점     한식
# 1      인천광역시 강화군          (주)보광호  일반음식점     회집
# 2      인천광역시 강화군          (주)섬고기  일반음식점    경양식
# 3      인천광역시 강화군         (주)장어마을  일반음식점     한식
# 4      인천광역시 강화군        (주)충남서산집  일반음식점     한식
# ...          ...             ...    ...    ...
# 31201   인천광역시 서구            힘찬장어  일반음식점     한식
# 31202   인천광역시 서구            힛트꼬치  일반음식점  호프/통닭
# 31203   인천광역시 서구             힌무발  일반음식점  호프/통닭
# 31204   인천광역시 서구         돈까스 청라점  일반음식점     일식
# 31205   인천광역시 서구          돈까스가좌점  일반음식점     일식
#
#                                                  업소주소 영업상태
# 0                          인천광역시 강화군 선원면 창리 418 외 1필지   정상
# 1                   인천광역시 강화군 길상면 해안남로619번길 21(1동 1층)   정상
# 2                            인천광역시 강화군 길상면 삼랑성길 4(1층)   정상
# 3                              인천광역시 강화군 길상면 해안남로 298   정상
# 4                          인천광역시 강화군 내가면 중앙로 1198(1층)   정상
# ...                                               ...  ...
# 31201                       인천광역시 서구 중봉대로 800(1층 경서동)   정상
# 31202                        인천광역시 서구 원창로240번길 3(가정동)   정상
# 31203                     인천광역시 서구 석남로 106(1층 일부 석남동)   정상
# 31204  인천광역시 서구 중봉대로612번길 10-12(109,110호 연희동, 청라프라자2)   정상
# 31205             인천광역시 서구 장고개로 277-1(청운프라자 101호 가좌동)   정상
#
# [31206 rows x 6 columns]

# %%
df = df.set_index('연번')

# %%
df['업태'].unique()
# Out:
# array(['한식', '회집', '경양식', nan, '중국식', '기타', '분식', '일식', '라이브카페',
#        '패밀리레스토랑', '김밥(도시락)', '호프/통닭', '식육(숯불구이)', '탕류(보신용)', '뷔페식',
#        '정종/대포집/소주방', '감성주점', '출장조리', '복어취급', '외국음식전문점(인도,태국등)', '냉면집',
#        '키즈카페'], dtype=object)

# %%
df['업태'].value_counts()
# Out:
# 한식                 12561
# 기타                  4883
# 호프/통닭               4380
# 식육(숯불구이)            1942
# 분식                  1931
# 중국식                 1432
# 정종/대포집/소주방          1329
# 일식                  1006
# 경양식                  977
# 회집                   748
# 외국음식전문점(인도,태국등)      251
# 탕류(보신용)              208
# 뷔페식                  207
# 김밥(도시락)              186
# 라이브카페                 97
# 패밀리레스토랑               47
# 출장조리                  31
# 냉면집                   31
# 감성주점                  30
# 키즈카페                  23
# 복어취급                  11
# Name: 업태, dtype: int64

# %%
df['업태'].isna().sum()
# Out:
# 351

# %%
df[df['업태'].isna()]
# Out:
#          인허가관할기관         업소명     업종   업태  \
# 연번
# 6      인천광역시 강화군   109 house  일반음식점  NaN
# 13     인천광역시 강화군       59쌀피자  일반음식점  NaN
# 14     인천광역시 강화군       59쌀피자  일반음식점  NaN
# 22     인천광역시 강화군  Cafe Millo  일반음식점  NaN
# 217    인천광역시 강화군        교동극장  일반음식점  NaN
# ...          ...         ...    ...  ...
# 32232   인천광역시 서구       피자플레이  일반음식점  NaN
# 32234   인천광역시 서구    피자헛인천검단점  일반음식점  NaN
# 32235   인천광역시 서구      피자헛청라점  일반음식점  NaN
# 32240   인천광역시 서구        피카소야  일반음식점  NaN
# 32519   인천광역시 서구      홀리빈코리아  일반음식점  NaN
#
#                                          업소주소 영업상태
# 연번
# 6                      인천광역시 강화군 양도면 해안서로 540   정상
# 13                     인천광역시 강화군 강화읍 강화대로 439   정상
# 14                     인천광역시 강화군 내가면 해안서로 902   정상
# 22                        인천광역시 강화군 강화읍 중앙로 9   정상
# 217                   인천광역시 강화군 교동면 대룡안길 36-1   정상
# ...                                       ...  ...
# 32232         인천광역시 서구 연희로13번길 7(연희동, 688-10)   정상
# 32234  인천광역시 서구 원당대로 669(마전동, 흥겨운마당 102,103호)   정상
# 32235         인천광역시 서구 청라커낼로319번길 3-5(1층 경서동)   정상
# 32240         인천광역시 서구 청라라임로122번길 8(101호 연희동)   정상
# 32519                인천광역시 서구 염곡로 662(1층 심곡동)   정상
#
# [351 rows x 6 columns]

# %%
df[df.업태 != '감성주점']['업태'].unique()
# Out:
# array(['한식', '회집', '경양식', nan, '중국식', '기타', '분식', '일식', '라이브카페',
#        '패밀리레스토랑', '김밥(도시락)', '호프/통닭', '식육(숯불구이)', '탕류(보신용)', '뷔페식',
#        '정종/대포집/소주방', '출장조리', '복어취급', '외국음식전문점(인도,태국등)', '냉면집', '키즈카페'],
#       dtype=object)

# %%
df = df[df.업태 != '감성주점']

# %%
df = df[df.업태 != '정종/대포집/소주방']

# %%
df = df[df.업태 != '라이브카페']

# %%
df
# Out:
#          인허가관할기관             업소명     업종     업태  \
# 연번
# 1      인천광역시 강화군  (유한)애플이엔씨 인천강화  일반음식점     한식
# 2      인천광역시 강화군          (주)보광호  일반음식점     회집
# 3      인천광역시 강화군          (주)섬고기  일반음식점    경양식
# 4      인천광역시 강화군         (주)장어마을  일반음식점     한식
# 5      인천광역시 강화군        (주)충남서산집  일반음식점     한식
# ...          ...             ...    ...    ...
# 32659   인천광역시 서구            힘찬장어  일반음식점     한식
# 32660   인천광역시 서구            힛트꼬치  일반음식점  호프/통닭
# 32662   인천광역시 서구             힌무발  일반음식점  호프/통닭
# 32663   인천광역시 서구         돈까스 청라점  일반음식점     일식
# 32664   인천광역시 서구          돈까스가좌점  일반음식점     일식
#
#                                                  업소주소 영업상태
# 연번
# 1                          인천광역시 강화군 선원면 창리 418 외 1필지   정상
# 2                   인천광역시 강화군 길상면 해안남로619번길 21(1동 1층)   정상
# 3                            인천광역시 강화군 길상면 삼랑성길 4(1층)   정상
# 4                              인천광역시 강화군 길상면 해안남로 298   정상
# 5                          인천광역시 강화군 내가면 중앙로 1198(1층)   정상
# ...                                               ...  ...
# 32659                       인천광역시 서구 중봉대로 800(1층 경서동)   정상
# 32660                        인천광역시 서구 원창로240번길 3(가정동)   정상
# 32662                     인천광역시 서구 석남로 106(1층 일부 석남동)   정상
# 32663  인천광역시 서구 중봉대로612번길 10-12(109,110호 연희동, 청라프라자2)   정상
# 32664             인천광역시 서구 장고개로 277-1(청운프라자 101호 가좌동)   정상
#
# [31206 rows x 6 columns]

# %%
df['업태'].unique()
# Out:
# array(['한식', '회집', '경양식', nan, '중국식', '기타', '분식', '일식', '패밀리레스토랑',
#        '김밥(도시락)', '호프/통닭', '식육(숯불구이)', '탕류(보신용)', '뷔페식', '출장조리', '복어취급',
#        '외국음식전문점(인도,태국등)', '냉면집', '키즈카페'], dtype=object)

# %%
df[df['업태'] == '호프/통닭']
# Out:
#          인허가관할기관      업소명     업종     업태                             업소주소 영업상태
# 연번
# 69     인천광역시 강화군    강사내통닭  일반음식점  호프/통닭  인천광역시 강화군 강화읍 강화대로409번길 4-2(1층)   정상
# 88     인천광역시 강화군    강화닭강정  일반음식점  호프/통닭    인천광역시 강화군 강화읍 북문길 6(1동 1층 3호)   정상
# 147    인천광역시 강화군     강화주당  일반음식점  호프/통닭         인천광역시 강화군 강화읍 동문안길 6(2층)   정상
# 149    인천광역시 강화군     강화치킨  일반음식점  호프/통닭           인천광역시 강화군 내가면 중앙로 1298   정상
# 180    인천광역시 강화군  고려산 호랑이  일반음식점  호프/통닭     인천광역시 강화군 송해면 강화대로 659-1(1층)   정상
# ...          ...      ...    ...    ...                              ...  ...
# 32640   인천광역시 서구     희노애락  일반음식점  호프/통닭            인천광역시 서구 고래울로 43(가좌동)   정상
# 32654   인천광역시 서구     힐링캠프  일반음식점  호프/통닭          인천광역시 서구 율도로 55(1층 신현동)   정상
# 32657   인천광역시 서구     힘센장어  일반음식점  호프/통닭      인천광역시 서구 승학로236번길 20-1(심곡동)   정상
# 32660   인천광역시 서구     힛트꼬치  일반음식점  호프/통닭         인천광역시 서구 원창로240번길 3(가정동)   정상
# 32662   인천광역시 서구      힌무발  일반음식점  호프/통닭      인천광역시 서구 석남로 106(1층 일부 석남동)   정상
#
# [4380 rows x 6 columns]

# %%
df
# Out:
#          인허가관할기관             업소명     업종     업태  \
# 연번
# 1      인천광역시 강화군  (유한)애플이엔씨 인천강화  일반음식점     한식
# 2      인천광역시 강화군          (주)보광호  일반음식점     회집
# 3      인천광역시 강화군          (주)섬고기  일반음식점    경양식
# 4      인천광역시 강화군         (주)장어마을  일반음식점     한식
# 5      인천광역시 강화군        (주)충남서산집  일반음식점     한식
# ...          ...             ...    ...    ...
# 32659   인천광역시 서구            힘찬장어  일반음식점     한식
# 32660   인천광역시 서구            힛트꼬치  일반음식점  호프/통닭
# 32662   인천광역시 서구             힌무발  일반음식점  호프/통닭
# 32663   인천광역시 서구         돈까스 청라점  일반음식점     일식
# 32664   인천광역시 서구          돈까스가좌점  일반음식점     일식
#
#                                                  업소주소 영업상태
# 연번
# 1                          인천광역시 강화군 선원면 창리 418 외 1필지   정상
# 2                   인천광역시 강화군 길상면 해안남로619번길 21(1동 1층)   정상
# 3                            인천광역시 강화군 길상면 삼랑성길 4(1층)   정상
# 4                              인천광역시 강화군 길상면 해안남로 298   정상
# 5                          인천광역시 강화군 내가면 중앙로 1198(1층)   정상
# ...                                               ...  ...
# 32659                       인천광역시 서구 중봉대로 800(1층 경서동)   정상
# 32660                        인천광역시 서구 원창로240번길 3(가정동)   정상
# 32662                     인천광역시 서구 석남로 106(1층 일부 석남동)   정상
# 32663  인천광역시 서구 중봉대로612번길 10-12(109,110호 연희동, 청라프라자2)   정상
# 32664             인천광역시 서구 장고개로 277-1(청운프라자 101호 가좌동)   정상
#
# [31206 rows x 6 columns]

# %%
df = df.reset_index().drop('연번', axis=1)

# %%
df
# Out:
#          인허가관할기관             업소명     업종     업태  \
# 0      인천광역시 강화군  (유한)애플이엔씨 인천강화  일반음식점     한식
# 1      인천광역시 강화군          (주)보광호  일반음식점     회집
# 2      인천광역시 강화군          (주)섬고기  일반음식점    경양식
# 3      인천광역시 강화군         (주)장어마을  일반음식점     한식
# 4      인천광역시 강화군        (주)충남서산집  일반음식점     한식
# ...          ...             ...    ...    ...
# 31201   인천광역시 서구            힘찬장어  일반음식점     한식
# 31202   인천광역시 서구            힛트꼬치  일반음식점  호프/통닭
# 31203   인천광역시 서구             힌무발  일반음식점  호프/통닭
# 31204   인천광역시 서구         돈까스 청라점  일반음식점     일식
# 31205   인천광역시 서구          돈까스가좌점  일반음식점     일식
#
#                                                  업소주소 영업상태
# 0                          인천광역시 강화군 선원면 창리 418 외 1필지   정상
# 1                   인천광역시 강화군 길상면 해안남로619번길 21(1동 1층)   정상
# 2                            인천광역시 강화군 길상면 삼랑성길 4(1층)   정상
# 3                              인천광역시 강화군 길상면 해안남로 298   정상
# 4                          인천광역시 강화군 내가면 중앙로 1198(1층)   정상
# ...                                               ...  ...
# 31201                       인천광역시 서구 중봉대로 800(1층 경서동)   정상
# 31202                        인천광역시 서구 원창로240번길 3(가정동)   정상
# 31203                     인천광역시 서구 석남로 106(1층 일부 석남동)   정상
# 31204  인천광역시 서구 중봉대로612번길 10-12(109,110호 연희동, 청라프라자2)   정상
# 31205             인천광역시 서구 장고개로 277-1(청운프라자 101호 가좌동)   정상
#
# [31206 rows x 6 columns]

# %%
df.to_csv('incheon.csv')

# %%
pd.read_csv('incheon.csv', index_col=0)
# Out:
#          인허가관할기관             업소명     업종     업태  \
# 0      인천광역시 강화군  (유한)애플이엔씨 인천강화  일반음식점     한식
# 1      인천광역시 강화군          (주)보광호  일반음식점     회집
# 2      인천광역시 강화군          (주)섬고기  일반음식점    경양식
# 3      인천광역시 강화군         (주)장어마을  일반음식점     한식
# 4      인천광역시 강화군        (주)충남서산집  일반음식점     한식
# ...          ...             ...    ...    ...
# 31201   인천광역시 서구            힘찬장어  일반음식점     한식
# 31202   인천광역시 서구            힛트꼬치  일반음식점  호프/통닭
# 31203   인천광역시 서구             힌무발  일반음식점  호프/통닭
# 31204   인천광역시 서구         돈까스 청라점  일반음식점     일식
# 31205   인천광역시 서구          돈까스가좌점  일반음식점     일식
#
#                                                  업소주소 영업상태
# 0                          인천광역시 강화군 선원면 창리 418 외 1필지   정상
# 1                   인천광역시 강화군 길상면 해안남로619번길 21(1동 1층)   정상
# 2                            인천광역시 강화군 길상면 삼랑성길 4(1층)   정상
# 3                              인천광역시 강화군 길상면 해안남로 298   정상
# 4                          인천광역시 강화군 내가면 중앙로 1198(1층)   정상
# ...                                               ...  ...
# 31201                       인천광역시 서구 중봉대로 800(1층 경서동)   정상
# 31202                        인천광역시 서구 원창로240번길 3(가정동)   정상
# 31203                     인천광역시 서구 석남로 106(1층 일부 석남동)   정상
# 31204  인천광역시 서구 중봉대로612번길 10-12(109,110호 연희동, 청라프라자2)   정상
# 31205             인천광역시 서구 장고개로 277-1(청운프라자 101호 가좌동)   정상
#
# [31206 rows x 6 columns]

# %%
df['인허가관할기관'].unique()
# Out:
# array(['인천광역시 강화군', '인천광역시 옹진군', '인천광역시 중구', '인천광역시 동구', '인천광역시 미추홀구',
#        '인천광역시 연수구', '인천광역시 남동구', '인천광역시 부평구', '인천광역시 계양구', '인천광역시 서구'],
#       dtype=object)

# %%
df['인허가관할기관'] + " " + df['업소명']
# Out:
# 0        인천광역시 강화군 (유한)애플이엔씨 인천강화
# 1                인천광역시 강화군 (주)보광호
# 2                인천광역시 강화군 (주)섬고기
# 3               인천광역시 강화군 (주)장어마을
# 4              인천광역시 강화군 (주)충남서산집
#                    ...
# 31201               인천광역시 서구 힘찬장어
# 31202               인천광역시 서구 힛트꼬치
# 31203                인천광역시 서구 힌무발
# 31204            인천광역시 서구 돈까스 청라점
# 31205             인천광역시 서구 돈까스가좌점
# Length: 31206, dtype: object

# %%
search_list = df['인허가관할기관'] + " " + df['업소명']

# %%
search_list[:100]
# Out:
# 0     인천광역시 강화군 (유한)애플이엔씨 인천강화
# 1             인천광역시 강화군 (주)보광호
# 2             인천광역시 강화군 (주)섬고기
# 3            인천광역시 강화군 (주)장어마을
# 4           인천광역시 강화군 (주)충남서산집
#                 ...
# 95            인천광역시 강화군 강화도령식당
# 96           인천광역시 강화군 강화도령화문석
# 97         인천광역시 강화군 강화도맛집 강맛도
# 98         인천광역시 강화군 강화도맛집 나들이
# 99     인천광역시 강화군 강화도맛집양선민참숯불장어
# Length: 100, dtype: object

# %%
# 크롤링

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import string
import time

datas = []
datas_menu = []

# %%
driver = webdriver.Chrome("C:/Users/5-25/chromedriver_win32/chromedriver") #selenium 사용에 필요한 chromedriver.exe 파일 경로 지정

# %%
def naverMapCrawling(search):
#     menus = []
    url = f"https://m.map.naver.com/search2/search.naver?query={search}"
    driver.get(url) 
    driver.implicitly_wait(5) 

    items = driver.find_elements(By.CSS_SELECTOR, '._item ')
    if not items:
        return

    # 검색결과 중 첫번째를 저장
    title = items[0].get_attribute('data-title')
    address = items[0].find_element(By.CSS_SELECTOR,'.item_address ').text.replace('주소보기\n', '')
    longitude = float(items[0].get_attribute('data-longitude'))
    latitude = float(items[0].get_attribute('data-latitude'))
    tel = items[0].get_attribute('data-tel')
    naverId = int(items[0].get_attribute('data-id'))
    category = items[0].find_element(By.TAG_NAME, 'em').text
    
    for character in string.punctuation:
        title = title.replace(character, '') # 특수기호 제거
        
    # 홈탭 이동
    driver.get(f'https://m.place.naver.com/place/{naverId}/home')
    time.sleep(1)
    try:
        button = driver.find_element(By.CSS_SELECTOR, '.zPfVt')
        button.click()
        time.sleep(1)
        summary = driver.find_element(By.CSS_SELECTOR, '.zPfVt').text           
    except:
        summary = np.nan
    print(summary)
    
    # 사진탭 이동
    driver.get(f'https://m.place.naver.com/place/{naverId}/photo')
    time.sleep(1)
    
    try:
        imgUrl = driver.find_element(By.ID, "업체사진_0").get_attribute('src')
    except:
        imgUrl = ''
        
    datas.append({
        "naverId" : naverId,
        "title" : title,
        "category" : category,
        "addr" : address,
        "longitude" : longitude,
        "latitude" : latitude,
        "tel" : tel,
        "imgUrl" : imgUrl,
        "summary" : summary
        })


    # 메뉴탭 이동
    driver.get(f'https://m.place.naver.com/restaurant/{naverId}/menu/list')
    time.sleep(1)
    
    # 일반 페이지인 경우
    menus = driver.find_elements(By.CLASS_NAME, 'P_Yxm')
    if menus:
        for menu in menus:
            name = menu.find_element(By.CLASS_NAME, 'Sqg65').text
            price = menu.find_element(By.CLASS_NAME, 'SSaNE').text
            introduction = menu.find_element(By.CLASS_NAME, 'eCaG_').text
            try:
                menuImg = menu.find_element(By.CLASS_NAME, 'K0PDV').get_attribute('style')
                menuImgUrl = menuImg.replace('width: 100px; height: 110px; background-image: url("', '').replace('");', '')
            except:
                menuImgUrl = ''

            datas_menu.append({
                "restrantId" : naverId,
                "menuName" : name,
                "price" : price,
                "introduction" : introduction,
                "menuImgUrl" : menuImgUrl
            })
    
    # 네이버 주문 페이지인 경우
    else:
        menus = driver.find_elements(By.CLASS_NAME, 'order_list_item')
        for menu in menus:
            name = menu.find_element(By.CLASS_NAME, 'tit').text
            price = menu.find_element(By.CLASS_NAME, 'price').text
            introduction = menu.find_element(By.CLASS_NAME, 'detail_txt').text
            try:
                menuImgUrl = menu.find_element(By.TAG_NAME, 'img').get_attribute('src')
            except:
                menuImgUrl = ''
            
            datas_menu.append({
                "restrantId" : naverId,
                "menuName" : name,
                "price" : price,
                "introduction" : introduction,
                "menuImgUrl" : menuImgUrl
            })

# %%
search_list = ['인천광역시 서구 힘찬장어', '인천광역시 강화군 보광호']

# %%
naverMapCrawling('인천광역시 강화군 보광호')
# Out:
# 오션뷰 맛집 보광호.
# 강화도에서 3대째 횟감을 직접 잡아 판매하는 어부 직영 횟집 보광호 입니다.
# 제철인 자연산 활어회와 꽃게, 왕새우 등 강화도에 오셔서 꼭 드셔야 할 음식을 맛있게 해드립니다.
#  mbc,kbs,obs,mbn 등 언론이나 매스컴에 많이 소개가 된 만큼 거짓이 아닌, 내가족이 먹는 다는 정성과 맛으로 보답을 해드리고 있으니 많이 찾아주세요.
# 또한 남녀노소 함께 할 수 있는 다양한 세트 메뉴 쭈꾸미,장어,꽃게,물회 등 싱싱한 해산물이 준비되어 있으며, 편안하게 식사할수 있도록 아이들 놀이방이 준비되어 있으니 믿고 찾아와 주세요!^0^
# 어서오시겨!

# %%
for search in search_list:
    naverMapCrawling(search)

# %%
for i, search in enumerate(search_list[:100]):
    naverMapCrawling(search)

# %%
print(datas)
# Out:
# [{'naverId': 16561600, 'title': '보광호', 'category': '생선회', 'addr': '인천광역시 강화군 길상면 해안남로619번길 21', 'longtitude': 126.4961852, 'latitude': 37.5983793, 'tel': '032-937-7111', 'imgUrl': 'https://search.pstatic.net/common/?autoRotate=true&type=w560_sharpen&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20220627_281%2F1656312077297PXT7f_JPEG%2FKakaoTalk_20220625_185715159_03.jpg', 'summary': '오션뷰 맛집 보광호.\n강화도에서 3대째 횟감을 직접 잡아 판매하는 어부 직영 횟집 보광호 입니다.\n제철인 자연산 활어회와 꽃게, 왕새우 등 강화도에 오셔서 꼭 드셔야 할 음식을 맛있게 해드립니다.\n mbc,kbs,obs,mbn 등 언론이나 매스컴에 많이 소개가 된 만큼 거짓이 아닌, 내가족이 먹는 다는 정성과 맛으로 보답을 해드리고 있으니 많이 찾아주세요.\n또한 남녀노소 함께 할 수 있는 다양한 세트 메뉴 쭈꾸미,장어,꽃게,물회 등 싱싱한 해산물이 준비되어 있으며, 편안하게 식사할수 있도록 아이들 놀이방이 준비되어 있으니 믿고 찾아와 주세요!^0^\n어서오시겨!'}]

# %%
print(datas_menu)
# Out:
# [{'restrantId': 16561600, 'menuName': 'A세트인기대표', 'price': '59,000원', 'introduction': '해산물모듬+제철모듬회+매운탕(지리탕)', 'menuImgUrl': 'https://ldb-phinf.pstatic.net/20220203_236/1643859679512uztsh_JPEG/image%285%29.jpg?type=f220_220_60_sharpen'}, {'restrantId': 16561600, 'menuName': 'A세트인기대표', 'price': '59,000원', 'introduction': '해산물모듬+제철모듬회+매운탕(지리탕)', 'menuImgUrl': 'https://ldb-phinf.pstatic.net/20220203_236/1643859679512uztsh_JPEG/image%285%29.jpg?type=f220_220_60_sharpen'}, {'restrantId': 16561600, 'menuName': 'A세트인기대표', 'price': '59,000원', 'introduction': '해산물모듬+제철모듬회+매운탕(지리탕)', 'menuImgUrl': 'https://ldb-phinf.pstatic.net/20220203_236/1643859679512uztsh_JPEG/image%285%29.jpg?type=f220_220_60_sharpen'}, {'restrantId': 16561600, 'menuName': '숭어', 'price': '25,000원', 'introduction': '', 'menuImgUrl': 'https://ldb-phinf.pstatic.net/20220207_135/1644229162736GhQpG_JPEG/%B0%AD%C8%AD%B5%B5%C2%FC%BC%FE%BE%EE.jpg?type=f220_220_60_sharpen'}, {'restrantId': 16561600, 'menuName': '광어', 'price': '40,000원', 'introduction': '', 'menuImgUrl': 'https://ldb-phinf.pstatic.net/20220207_188/1644229088568hxdPf_JPEG/%B1%A4%BE%EE.jpg?type=f220_220_60_sharpen'}, {'restrantId': 16561600, 'menuName': '우럭', 'price': '40,000원', 'introduction': '', 'menuImgUrl': 'https://ldb-phinf.pstatic.net/20220207_115/1644228991168Mn4KV_JPEG/%BF%EC%B7%B0.jpg?type=f220_220_60_sharpen'}, {'restrantId': 16561600, 'menuName': '도미', 'price': '50,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '농어', 'price': '50,000원', 'introduction': '', 'menuImgUrl': 'https://ldb-phinf.pstatic.net/20220207_159/1644229129813G9tAV_JPEG/%B3%F3%BE%EE.jpg?type=f220_220_60_sharpen'}, {'restrantId': 16561600, 'menuName': '해산물모듬', 'price': '30,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '멍게', 'price': '15,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '낙지', 'price': '20,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '전복', 'price': '20,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '가리비회', 'price': '25,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '단호박꽃게탕', 'price': '60,000원', 'introduction': '', 'menuImgUrl': 'https://ldb-phinf.pstatic.net/20220203_152/1643859623659gjqkp_JPEG/image%283%29.jpg?type=f220_220_60_sharpen'}, {'restrantId': 16561600, 'menuName': '연포탕', 'price': '50,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '우럭탕', 'price': '50,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '콘치즈', 'price': '2,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '날치알덮밥', 'price': '2,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '셀프주먹밥', 'price': '3,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '고등어구이', 'price': '8,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '어린이돈까스', 'price': '8,000원', 'introduction': '', 'menuImgUrl': ''}, {'restrantId': 16561600, 'menuName': '왕새우튀김', 'price': '10,000원', 'introduction': '', 'menuImgUrl': ''}]

# %%
df
# Out:
#          인허가관할기관             업소명     업종     업태  \
# 0      인천광역시 강화군  (유한)애플이엔씨 인천강화  일반음식점     한식
# 1      인천광역시 강화군          (주)보광호  일반음식점     회집
# 2      인천광역시 강화군          (주)섬고기  일반음식점    경양식
# 3      인천광역시 강화군         (주)장어마을  일반음식점     한식
# 4      인천광역시 강화군        (주)충남서산집  일반음식점     한식
# ...          ...             ...    ...    ...
# 31201   인천광역시 서구            힘찬장어  일반음식점     한식
# 31202   인천광역시 서구            힛트꼬치  일반음식점  호프/통닭
# 31203   인천광역시 서구             힌무발  일반음식점  호프/통닭
# 31204   인천광역시 서구         돈까스 청라점  일반음식점     일식
# 31205   인천광역시 서구          돈까스가좌점  일반음식점     일식
#
#                                                  업소주소 영업상태
# 0                          인천광역시 강화군 선원면 창리 418 외 1필지   정상
# 1                   인천광역시 강화군 길상면 해안남로619번길 21(1동 1층)   정상
# 2                            인천광역시 강화군 길상면 삼랑성길 4(1층)   정상
# 3                              인천광역시 강화군 길상면 해안남로 298   정상
# 4                          인천광역시 강화군 내가면 중앙로 1198(1층)   정상
# ...                                               ...  ...
# 31201                       인천광역시 서구 중봉대로 800(1층 경서동)   정상
# 31202                        인천광역시 서구 원창로240번길 3(가정동)   정상
# 31203                     인천광역시 서구 석남로 106(1층 일부 석남동)   정상
# 31204  인천광역시 서구 중봉대로612번길 10-12(109,110호 연희동, 청라프라자2)   정상
# 31205             인천광역시 서구 장고개로 277-1(청운프라자 101호 가좌동)   정상
#
# [31206 rows x 6 columns]

# %%
df['업소명'][50:100]
# Out:
# 50             가나안오리
# 51               가마솥
# 52           가마솥 토종닭
# 53               가비다
# 54         가장 맛있는 족발
# 55             가정식백반
# 56             가정식백반
# 57            가즈아감자탕
# 58            갈치왕코다리
# 59              감나무골
# 60              감동국수
# 61              감동김밥
# 62                감성
# 63          강나루 풍천장어
# 64              강남족발
# 65            강남풍천장어
# 66            강바우순대국
# 67             강사내통닭
# 68              강서식당
# 69              강서식당
# 70             강인음식점
# 71          강화 닭과칼국수
# 72    강화 모또모 바베큐 하우스
# 73           강화 신토오리
# 74           강화 홀리데이
# 75         강화갯벌장어:새우
# 76         강화갯벌장어직판장
# 77            강화고기국수
# 78               강화골
# 79              강화국밥
# 80               강화길
# 81             강화김밥집
# 82          강화꽃게사랑식당
# 83            강화꽃게전문
# 84             강화꽃게집
# 85           강화녹두삼계탕
# 86             강화닭강정
# 87               강화댁
# 88          강화도 마리마리
# 89          강화도 모모카페
# 90          강화도 모모카페
# 91        강화도 진 한우곰탕
# 92         강화도꽃마니에뜨락
# 93              강화도령
# 94            강화도령김밥
# 95            강화도령식당
# 96           강화도령화문석
# 97         강화도맛집 강맛도
# 98         강화도맛집 나들이
# 99     강화도맛집양선민참숯불장어
# Name: 업소명, dtype: object

# %%
df['업소명'][101]
# Out:
# '강화도짬뽕'

# %%
df.iloc[399, :]
# Out:
# 인허가관할기관                    인천광역시 강화군
# 업소명                           돈대비빔국수
# 업종                             일반음식점
# 업태                                한식
# 업소주소       인천광역시 강화군 길상면 해안동로 85(1층)
# 영업상태                              정상
# Name: 399, dtype: object
